# %% [markdown]
# # nuScenes devkit tutorial
#
# Welcome to the nuScenes tutorial. This demo assumes the database itself is available at `/data/sets/nuscenes`, and loads a mini version of the full dataset.

# %% [markdown]
# ## A Gentle Introduction to nuScenes
#
# In this part of the tutorial, let us go through a top-down introduction of our database. Our dataset comprises of elemental building blocks that are the following:
#
# 1. `log` - Log information from which the data was extracted.
# 2. `scene` - 20 second snippet of a car's journey.
# 3. `sample` - An annotated snapshot of a scene at a particular timestamp.
# 4. `sample_data` - Data collected from a particular sensor.
# 5. `ego_pose` - Ego vehicle poses at a particular timestamp.
# 6. `sensor` - A specific sensor type.
# 7. `calibrated sensor` - Definition of a particular sensor as calibrated on a particular vehicle.
# 8. `instance` - Enumeration of all object instance we observed.
# 9. `category` - Taxonomy of object categories (e.g. vehicle, human).
# 10. `attribute` - Property of an instance that can change while the category remains the same.
# 11. `visibility` - Fraction of pixels visible in all the images collected from 6 different cameras.
# 12. `sample_annotation` - An annotated instance of an object within our interest.
# 13. `map` - Map data that is stored as binary semantic masks from a top-down view.
#
# The database schema is visualized below. For more information see the [nuScenes schema](https://github.com/nutonomy/nuscenes-devkit/blob/master/docs/schema_nuscenes.md) page.
# ![](https://www.nuscenes.org/public/images/nuscenes-schema.svg)

# %% [markdown]
# ## Google Colab (optional)
#
# <br>
# <a href="https://colab.research.google.com/github/nutonomy/nuscenes-devkit/blob/master/python-sdk/tutorials/nuscenes_tutorial.ipynb">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" align="left">
# </a>
# <br>
#
# If you are running this notebook in Google Colab, you can uncomment the cell below and run it; everything will be set up nicely for you. Otherwise, manually set up everything.

# %%
# !mkdir -p /data/sets/nuscenes  # Make the directory to store the nuScenes dataset in.

# !wget https://www.nuscenes.org/data/v1.0-mini.tgz  # Download the nuScenes mini split.
# !unzip /dataset.zip -d /data/sets/nuscenes
# !tar -xf v1.0-mini.tgz -C /data/sets/nuscenes  # Uncompress the nuScenes mini split.

# !pip install nuscenes-devkit &> /dev/null  # Install nuScenes.
# Out:
# Archive:  /dataset.zip
#    creating: /data/sets/nuscenes/dataset/
#    creating: /data/sets/nuscenes/dataset/lidarseg/
#    creating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/63cc36ab8e9c4a2f7e173fc3cbea20ad.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/efeb1c8ace7646c254aea644cecc9300.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/c75249ca5c640f10ca62f2faa6120aa7.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/e5d92ddce84a0b1e447ae76762267813.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/8e4357a480528fb54681463d958692e5.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/279d76e62a708d48d1ae273b2b5a2355.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/ac4a889d5a7525dd3854c31c2bc03125.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/32ad04196b39d23b231b2e5d7f1829c7.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/723c5c6c54f6ca017a654dcbbe3355be.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/d120c09be6e93af668128c9dc60b8d36.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/bf79302a7e78688f9f929af6566207f3.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/4dc460114b57ee197e95b6bc8569036b.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/212618dabbeefe431600531d9f3780ca.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/7d76b111e4b4a6a0ab79ffc8d5ff396d.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/8393637396f30552eaa22d5cb4d90b67.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/8fba21d99f1309047e13c790c01a0621.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/d53b2e0e3b4d46c983e83000c1c4b309.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/8b56b9fb7ef8db644d973e930e8532ff.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/488f2b3ce92daa24807b33de6afa8632.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/d277145866796cda52c4c0ab691d3038.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/1eea2aa335ba1367099f67774385bd1e.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/2ae3971853daff90e29b44634fe434b8.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/de84e0c59546cda4870047baafa2ddae.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/a979e0d0467fdbb3c45dda6004b115dd.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/d93937c56b676115edbf71c1fc35f156.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/2bcec26ffc54942912247837327ade22.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/7459017b7d9655e6c6b0fb4251eed081.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/4527ec6935a987a9acbf336877c4618b.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/a9d5b6258898704c438eb52c3d2eef27.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/2a8081ad2916b60d3928430ef4abd86c.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/bc20fed80747c5dde90e3530d947e90e.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/445f430133fd4a331ef1d2fcd37cf7bc.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/5848ee06775829d83cb4ef72c73ad468.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/2505f61c433849a8d3d39d8fa4c26201.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/62a2d892012e67329a901b4d478d24d2.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/59c683c92202ffbaad0bffd3a2bffaff.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/004f7089f2a66c4fb619e9ea35be48bd.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/22529067a8f183136b4823a3e5e19808.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/b079a1e5a1e0a3dedb6d8b844721028e.bin
#   inflating: /data/sets/nuscenes/dataset/lidarseg/v1.0-trainval/3540a896443171cfef555607ec9ecfcc.bin
#    creating: /data/sets/nuscenes/dataset/v1.0-trainval/
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/attribute.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/calibrated_sensor.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/ego_pose.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/instance.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/log.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/map.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/sample.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/sample_annotation.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/sample_data.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/scene.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/sensor.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/visibility.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/progress.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/category.json
#   inflating: /data/sets/nuscenes/dataset/v1.0-trainval/lidarseg.json
#    creating: /data/sets/nuscenes/dataset/maps/
#   inflating: /data/sets/nuscenes/dataset/maps/13495e9329a1666a9050697fdf00a206.png
#    creating: /data/sets/nuscenes/dataset/samples/
#    creating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_83828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_88828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_93828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_98828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_103828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_108828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_113828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_118828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_123828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_128828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_133828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_138828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_143828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_148828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_153828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_158828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_163828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_168828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_173828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_178828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_183828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_188828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_193828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_198828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_203828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_208828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_213828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_218828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_223828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_228828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_233828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_238828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_243828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_248828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_253828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_258828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_263828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_268828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_273828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_278828859.jpg
#    creating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_83828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_88828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_93828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_98828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_103828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_108828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_113828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_118828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_123828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_128828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_133828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_138828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_143828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_148828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_153828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_158828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_163828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_168828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_173828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_178828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_183828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_188828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_193828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_198828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_203828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_208828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_213828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_218828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_223828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_228828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_233828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_238828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_243828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_248828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_253828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_258828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_263828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_268828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_273828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_RIGHT_278828859.jpg
#    creating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_83828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_88828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_93828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_98828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_103828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_108828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_113828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_118828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_123828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_128828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_133828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_138828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_143828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_148828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_153828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_158828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_163828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_168828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_173828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_178828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_183828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_188828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_193828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_198828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_203828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_208828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_213828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_218828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_223828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_228828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_233828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_238828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_243828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_248828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_253828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_258828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_263828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_268828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_273828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_LEFT_278828859.jpg
#    creating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_83828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_88828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_93828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_98828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_103828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_108828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_113828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_118828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_123828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_128828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_133828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_138828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_143828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_148828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_153828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_158828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_163828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_168828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_173828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_178828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_183828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_188828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_193828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_198828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_203828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_208828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_213828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_218828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_223828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_228828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_233828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_238828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_243828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_248828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_253828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_258828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_263828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_268828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_273828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_LEFT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_LEFT_278828859.jpg
#    creating: /data/sets/nuscenes/dataset/samples/CAM_BACK/
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_83828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_88828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_93828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_98828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_103828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_108828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_113828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_118828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_123828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_128828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_133828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_138828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_143828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_148828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_153828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_158828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_163828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_168828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_173828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_178828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_183828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_188828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_193828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_198828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_203828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_208828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_213828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_218828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_223828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_228828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_233828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_238828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_243828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_248828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_253828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_258828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_263828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_268828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_273828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK/c0003-2023-01-09-10-45-20+0800_CAM_BACK_278828859.jpg
#    creating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_83828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_88828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_93828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_98828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_103828863.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_108828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_113828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_118828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_123828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_128828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_133828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_138828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_143828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_148828862.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_153828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_158828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_163828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_168828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_173828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_178828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_183828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_188828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_193828861.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_198828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_203828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_208828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_213828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_218828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_223828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_228828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_233828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_238828860.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_243828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_248828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_253828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_258828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_263828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_268828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_273828859.jpg
#   inflating: /data/sets/nuscenes/dataset/samples/CAM_BACK_RIGHT/c0003-2023-01-09-10-45-20+0800_CAM_BACK_RIGHT_278828859.jpg
#    creating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_84228863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_88828863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_94228863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_98828863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_104228863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_108828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_114228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_118828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_124228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_128828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_134228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_138828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_144228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_148828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_154228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_158828861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_164228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_168828861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_174228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_178828861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_184228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_188828861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_194228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_198828860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_204228860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_208828860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_214228860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_218828860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_224228860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_228828860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_234228860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_238828860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_244228859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_248828859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_254228859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_258828859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_264228859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_268828859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_274228859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_278828859.pcd
#    creating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_84228863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_88828863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_94228863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_98828863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_104228863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_108828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_114228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_118828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_124228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_128828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_134228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_138828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_144228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_148828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_154228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_158828861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_164228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_168828861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_174228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_178828861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_184228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_188828861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_194228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_198828860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_204228860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_208828860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_214228860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_218828860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_224228860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_228828860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_234228860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_238828860.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_244228859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_248828859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_254228859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_258828859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_264228859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_268828859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_274228859.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_RIGHT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_RIGHT_278828859.pcd
#    creating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_84228863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_88828863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_94228863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_98828863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_104228863.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_108828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_114228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_118828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_124228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_128828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_134228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_138828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_144228862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_148828862.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_154228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_158828861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_164228861.pcd
#   inflating: /data/sets/nuscenes/dataset/samples/RADAR_FRONT_LEFT/c0003-2023-01-09-10-45-20+0800_RADAR_FRONT_LEFT_168828861.pcd
# ...
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_205128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_205628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_206128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_206628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_207128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_207628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_208128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_208628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_209628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_210128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_210628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_211128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_211628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_212128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_212628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_213128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_213628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_214628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_215128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_215628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_216128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_216628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_217128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_217628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_218128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_218628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_219628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_220128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_220628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_221128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_221628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_222128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_222628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_223128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_223628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_224628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_225128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_225628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_226128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_226628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_227128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_227628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_228128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_228628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_229628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_230128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_230628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_231128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_231628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_232128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_232628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_233128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_233628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_234628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_235128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_235628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_236128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_236628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_237128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_237628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_238128860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_238628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_239628860.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_240128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_240628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_241128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_241628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_242128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_242628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_243128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_243628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_244628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_245128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_245628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_246128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_246628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_247128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_247628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_248128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_248628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_249628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_250128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_250628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_251128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_251628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_252128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_252628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_253128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_253628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_254628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_255128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_255628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_256128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_256628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_257128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_257628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_258128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_258628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_259628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_260128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_260628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_261128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_261628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_262128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_262628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_263128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_263628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_264628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_265128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_265628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_266128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_266628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_267128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_267628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_268128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_268628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_269628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_270128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_270628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_271128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_271628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_272128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_272628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_273128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_273628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_274628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_275128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_275628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_276128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_276628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_277128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_277628859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_278128859.pcd.bin
#   inflating: /data/sets/nuscenes/dataset/sweeps/LIDAR_TOP/c0003-2023-01-09-10-45-20+0800_LIDAR_TOP_278628859.pcd.bin

# %% [markdown]
# ## Initialization

# %%
# %matplotlib inline
from nuscenes.nuscenes import NuScenes

nusc = NuScenes(version='v1.0-trainval', dataroot='/data/sets/nuscenes/dataset', verbose=True)
# Out:
# ======
# Loading NuScenes tables for version v1.0-trainval...
# Loading nuScenes-lidarseg...
# 32 category,
# 8 attribute,
# 4 visibility,
# 1 instance,
# 12 sensor,
# 14 calibrated_sensor,
# 3140 ego_pose,
# 1 log,
# 1 scene,
# 40 sample,
# 3140 sample_data,
# 26 sample_annotation,
# 1 map,
# 40 lidarseg,
# Done loading in 0.099 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 0.0 seconds.
# ======

# %% [markdown]
# ## A look at the dataset

# %% [markdown]
# ### 1. `scene`

# %% [markdown]
# nuScenes is a large scale database that features annotated samples across ***1000 scenes*** of approximately 20 seconds each. Let's take a look at the scenes that we have in the loaded database.

# %%
nusc.list_scenes()
# Out:
# scene-0-1, test  [70-01-01 00:01:24]  195s, chengdu, #anns:25

# %% [markdown]
# Let's look at a scene metadata

# %%
my_scene = nusc.scene[0]
my_scene
# Out:
# {'name': 'scene-0-1',
#  'token': 'fda211ce986f67d3db14b88eeb1f7ec6',
#  'description': 'test',
#  'log_token': 'aeb40c002db729fd8d675c752dd58a3a',
#  'nbr_samples': 40,
#  'first_sample_token': 'f1a86c6d1db0995c9709d9bc2da68656',
#  'last_sample_token': 'b5c626bedde6e025de0e8b6a38a6cf0a'}

# %% [markdown]
# ### 2. `sample`

# %% [markdown]
# In scenes, we annotate our data every half a second (2 Hz).
#
# We define `sample` as an ***annotated keyframe of a scene at a given timestamp***. A keyframe is a frame where the time-stamps of data from all the sensors should be very close to the time-stamp of the sample it points to.
#
# Now, let us look at the first annotated sample in this scene.

# %%
first_sample_token = my_scene['first_sample_token']

# The rendering command below is commented out because it tends to crash in notebooks
# nusc.render_sample(first_sample_token)

# %% [markdown]
# Let's examine its metadata

# %%
my_sample = nusc.get('sample', first_sample_token)
my_sample
# Out:
# {'token': 'f1a86c6d1db0995c9709d9bc2da68656',
#  'timestamp': 84428863,
#  'prev': '',
#  'next': '7651dedd90526ef4335a22a3336261af',
#  'scene_token': 'fda211ce986f67d3db14b88eeb1f7ec6',
#  'data': {'CAM_FRONT': '06904f00bd9c6a9405b96718dc1457b0',
#   'CAM_FRONT_RIGHT': 'cd570fd8f2ff943544df94ade5ffe597',
#   'CAM_FRONT_LEFT': 'deedc60d2960b9a1f4ce9d57ec0d71e8',
#   'CAM_BACK_LEFT': 'abde3f5d448d69626ae2c7179bb96684',
#   'CAM_BACK': '8f25fbfbb22c08818f7a1635c6f54ac7',
#   'CAM_BACK_RIGHT': '384217a6283fc48e49c70e1796c6032b',
#   'RADAR_FRONT': '902e0d66349b61141c1281074b59c02a',
#   'RADAR_FRONT_RIGHT': '4fc391e5bbdfb65aea2a221af317a083',
#   'RADAR_FRONT_LEFT': 'e4280617dd01dc1fe484e03682d5486e',
#   'RADAR_BACK_RIGHT': '5ee31e4ef93fc7f64cc70fd718a7366a',
#   'RADAR_BACK_LEFT': '794167037183c6ac95a42ae13bca3ef4',
#   'LIDAR_TOP': '63cc36ab8e9c4a2f7e173fc3cbea20ad'},
#  'anns': []}

# %% [markdown]
# A useful method is  `list_sample()` which lists all related `sample_data` keyframes and `sample_annotation` associated with a `sample` which we will discuss in detail in the subsequent parts.

# %%
nusc.list_sample(my_sample['token'])
# Out:
# Sample: f1a86c6d1db0995c9709d9bc2da68656
#
# sample_data_token: 06904f00bd9c6a9405b96718dc1457b0, mod: camera, channel: CAM_FRONT
# sample_data_token: cd570fd8f2ff943544df94ade5ffe597, mod: camera, channel: CAM_FRONT_RIGHT
# sample_data_token: deedc60d2960b9a1f4ce9d57ec0d71e8, mod: camera, channel: CAM_FRONT_LEFT
# sample_data_token: abde3f5d448d69626ae2c7179bb96684, mod: camera, channel: CAM_BACK_LEFT
# sample_data_token: 8f25fbfbb22c08818f7a1635c6f54ac7, mod: camera, channel: CAM_BACK
# sample_data_token: 384217a6283fc48e49c70e1796c6032b, mod: camera, channel: CAM_BACK_RIGHT
# sample_data_token: 902e0d66349b61141c1281074b59c02a, mod: radar, channel: RADAR_FRONT
# sample_data_token: 4fc391e5bbdfb65aea2a221af317a083, mod: radar, channel: RADAR_FRONT_RIGHT
# sample_data_token: e4280617dd01dc1fe484e03682d5486e, mod: radar, channel: RADAR_FRONT_LEFT
# sample_data_token: 5ee31e4ef93fc7f64cc70fd718a7366a, mod: radar, channel: RADAR_BACK_RIGHT
# sample_data_token: 794167037183c6ac95a42ae13bca3ef4, mod: radar, channel: RADAR_BACK_LEFT
# sample_data_token: 63cc36ab8e9c4a2f7e173fc3cbea20ad, mod: lidar, channel: LIDAR_TOP

# %% [markdown]
# ### 3. `sample_data`

# %% [markdown]
# The nuScenes dataset contains data that is collected from a full sensor suite. Hence, for each snapshot of a scene, we provide references to a family of data that is collected from these sensors.
#
# We provide a `data` key to access these:

# %%
my_sample['data']
# Out:
# {'CAM_FRONT': '06904f00bd9c6a9405b96718dc1457b0',
#  'CAM_FRONT_RIGHT': 'cd570fd8f2ff943544df94ade5ffe597',
#  'CAM_FRONT_LEFT': 'deedc60d2960b9a1f4ce9d57ec0d71e8',
#  'CAM_BACK_LEFT': 'abde3f5d448d69626ae2c7179bb96684',
#  'CAM_BACK': '8f25fbfbb22c08818f7a1635c6f54ac7',
#  'CAM_BACK_RIGHT': '384217a6283fc48e49c70e1796c6032b',
#  'RADAR_FRONT': '902e0d66349b61141c1281074b59c02a',
#  'RADAR_FRONT_RIGHT': '4fc391e5bbdfb65aea2a221af317a083',
#  'RADAR_FRONT_LEFT': 'e4280617dd01dc1fe484e03682d5486e',
#  'RADAR_BACK_RIGHT': '5ee31e4ef93fc7f64cc70fd718a7366a',
#  'RADAR_BACK_LEFT': '794167037183c6ac95a42ae13bca3ef4',
#  'LIDAR_TOP': '63cc36ab8e9c4a2f7e173fc3cbea20ad'}

# %% [markdown]
# Notice that the keys are referring to the different sensors that form our sensor suite. Let's take a look at the metadata of a `sample_data` taken from `CAM_FRONT`.

# %%
sensor = 'CAM_FRONT'
cam_front_data = nusc.get('sample_data', my_sample['data'][sensor])
cam_front_data
# Out:
# {'token': '06904f00bd9c6a9405b96718dc1457b0',
#  'sample_token': 'f1a86c6d1db0995c9709d9bc2da68656',
#  'ego_pose_token': '06904f00bd9c6a9405b96718dc1457b0',
#  'calibrated_sensor_token': 'db118bdf3369c52f459c19cd4d52a768',
#  'timestamp': 83828863,
#  'fileformat': 'jpg',
#  'is_key_frame': True,
#  'height': 900,
#  'width': 1600,
#  'prev': '160a8d15b2c06ecb47fd0b23ae2490c1',
#  'next': '44525a771664cf4d36255a65906ab10a',
#  'filename': 'samples/CAM_FRONT/c0003-2023-01-09-10-45-20+0800_CAM_FRONT_83828863.jpg',
#  'sensor_modality': 'camera',
#  'channel': 'CAM_FRONT'}

# %% [markdown]
# We can also render the `sample_data` at a particular sensor.

# %%
nusc.render_sample_data(cam_front_data['token'])

# %% [markdown]
# ### 4. `sample_annotation`

# %% [markdown]
# `sample_annotation` refers to any ***bounding box defining the position of an object seen in a sample***. All location data is given with respect to the global coordinate system. Let's examine an example from our `sample` above.

# %%
my_annotation_token = my_sample['anns'][18]
my_annotation_metadata =  nusc.get('sample_annotation', my_annotation_token)
my_annotation_metadata

# %% [markdown]
# We can also render an annotation to have a closer look.

# %%
nusc.render_annotation(my_annotation_token)

# %% [markdown]
# ### 5. `instance`

# %% [markdown]
# Object instance are instances that need to be detected or tracked by an AV (e.g a particular vehicle, pedestrian). Let us examine an instance metadata

# %%
my_instance = nusc.instance[599]
my_instance

# %% [markdown]
# We generally track an instance across different frames in a particular scene. However, we do not track them across different scenes. In this example, we have 16 annotated samples for this instance across a particular scene.

# %%
instance_token = my_instance['token']
nusc.render_instance(instance_token)

# %% [markdown]
# An instance record takes note of its first and last annotation token. Let's render them

# %%
print("First annotated sample of this instance:")
nusc.render_annotation(my_instance['first_annotation_token'])

# %%
print("Last annotated sample of this instance")
nusc.render_annotation(my_instance['last_annotation_token'])

# %% [markdown]
# ### 6. `category`

# %% [markdown]
# A `category` is the object assignment of an annotation.  Let's look at the category table we have in our database. The table contains the taxonomy of different object categories and also list the subcategories (delineated by a period).

# %%
nusc.list_categories()

# %% [markdown]
# A category record contains the name and the description of that particular category.

# %%
nusc.category[9]

# %% [markdown]
# Refer to `instructions_nuscenes.md` for the definitions of the different categories.

# %% [markdown]
# ### 7. `attribute`

# %% [markdown]
# An `attribute` is a property of an instance that may change throughout different parts of a scene while the category remains the same. Here we list the provided attributes and the number of annotations associated with a particular attribute.

# %%
nusc.list_attributes()

# %% [markdown]
# Let's take a look at an example how an attribute may change over one scene

# %%
my_instance = nusc.instance[27]
first_token = my_instance['first_annotation_token']
last_token = my_instance['last_annotation_token']
nbr_samples = my_instance['nbr_annotations']
current_token = first_token

i = 0
found_change = False
while current_token != last_token:
    current_ann = nusc.get('sample_annotation', current_token)
    current_attr = nusc.get('attribute', current_ann['attribute_tokens'][0])['name']

    if i == 0:
        pass
    elif current_attr != last_attr:
        print("Changed from `{}` to `{}` at timestamp {} out of {} annotated timestamps".format(last_attr, current_attr, i, nbr_samples))
        found_change = True

    next_token = current_ann['next']
    current_token = next_token
    last_attr = current_attr
    i += 1

# %% [markdown]
# ### 8. `visibility`

# %% [markdown]
# `visibility` is defined as the fraction of pixels of a particular annotation that are visible over the 6 camera feeds, grouped into 4 bins.

# %%
nusc.visibility

# %% [markdown]
# Let's look at an example `sample_annotation` with 80-100% visibility

# %%
anntoken = 'a7d0722bce164f88adf03ada491ea0ba'
visibility_token = nusc.get('sample_annotation', anntoken)['visibility_token']

print("Visibility: {}".format(nusc.get('visibility', visibility_token)))
nusc.render_annotation(anntoken)

# %% [markdown]
# Let's look at an example `sample_annotation` with 0-40% visibility

# %%
anntoken = '9f450bf6b7454551bbbc9a4c6e74ef2e'
visibility_token = nusc.get('sample_annotation', anntoken)['visibility_token']

print("Visibility: {}".format(nusc.get('visibility', visibility_token)))
nusc.render_annotation(anntoken)

# %% [markdown]
# ### 9. `sensor`

# %% [markdown]
# The nuScenes dataset consists of data collected from our full sensor suite which consists of:
# - 1 x LIDAR,
# - 5 x RADAR,
# - 6 x cameras,

# %%
nusc.sensor

# %% [markdown]
# Every `sample_data` has a record on which `sensor` the data is collected from (note the "channel" key)

# %%
nusc.sample_data[10]

# %% [markdown]
# ### 10. `calibrated_sensor`

# %% [markdown]
# `calibrated_sensor` consists of the definition of a particular sensor (lidar/radar/camera) as calibrated on a particular vehicle. Let us look at an example.

# %%
nusc.calibrated_sensor[0]

# %% [markdown]
# Note that the `translation` and the `rotation` parameters are given with respect to the ego vehicle body frame.

# %% [markdown]
# ### 11. `ego_pose`

# %% [markdown]
# `ego_pose` contains information about the location (encoded in `translation`) and the orientation (encoded in `rotation`) of the ego vehicle, with respect to the global coordinate system.

# %%
nusc.ego_pose[0]

# %% [markdown]
# Note that the number of `ego_pose` records in our loaded database is the same as the number of `sample_data` records. These two records exhibit a one-to-one correspondence.

# %% [markdown]
# ### 12. `log`
#
# The `log` table contains log information from which the data was extracted. A `log` record corresponds to one journey of our ego vehicle along a predefined route. Let's check the number of logs and the metadata of a log.

# %%
print("Number of `logs` in our loaded database: {}".format(len(nusc.log)))

# %%
nusc.log[0]

# %% [markdown]
# Notice that it contains a variety of information such as the date and location of the log collected. It also gives out information about the map from where the data was collected. Note that one log can contain multiple non-overlapping scenes.

# %% [markdown]
# ### 13. `map`

# %% [markdown]
# Map information is stored as binary semantic masks from a top-down view. Let's check the number of maps and metadata of a map.

# %%
print("There are {} maps masks in the loaded dataset".format(len(nusc.map)))

# %%
nusc.map[0]

# %% [markdown]
# ## nuScenes Basics

# %% [markdown]
# Let's get a bit technical.
#
# The NuScenes class holds several tables. Each table is a list of records, and each record is a dictionary. For example the first record of the category table is stored at:

# %%
nusc.category[0]
# Out:
# {'token': '4d3ef1e8c6f3a20cdd450ecf205282be',
#  'name': 'noise',
#  'description': 'Any lidar return that does not correspond to a physical object, such as dust, vapor, noise, fog, raindrops, smoke and reflections.',
#  'index': 0}

# %% [markdown]
# The category table is simple: it holds the fields `name` and `description`. It also has a `token` field, which is a unique record identifier. Since the record is a dictionary, the token can be accessed like so:

# %%
cat_token = nusc.category[0]['token']
cat_token
# Out:
# '4d3ef1e8c6f3a20cdd450ecf205282be'

# %% [markdown]
# If you know the `token` for any record in the DB you can retrieve the record by doing

# %%
nusc.get('category', cat_token)

# %% [markdown]
# _As you can notice, we have recovered the same record!_

# %% [markdown]
# OK, that was easy. Let's try something harder. Let's look at the `sample_annotation` table.

# %%
nusc.sample_annotation[0]

# %% [markdown]
# This also has a `token` field (they all do). In addition, it has several fields of the format [a-z]*\_token, _e.g._ instance_token. These are foreign keys in database terminology, meaning they point to another table.
# Using `nusc.get()` we can grab any of these in constant time. For example, let's look at the visibility record.

# %%
nusc.get('visibility', nusc.sample_annotation[0]['visibility_token'])

# %% [markdown]
# The visibility records indicate how much of an object was visible when it was annotated.
#
# Let's also grab the `instance_token`

# %%
one_instance = nusc.get('instance', nusc.sample_annotation[0]['instance_token'])
one_instance

# %% [markdown]
# This points to the `instance` table. This table enumerate the object _instances_ we have encountered in each
# scene. This way we can connect all annotations of a particular object.
#
# If you look carefully at the README tables, you will see that the sample_annotation table points to the instance table,
# but the instance table doesn't list all annotations that point to it.
#
# So how can we recover all sample_annotations for a particular object instance? There are two ways:
#
# 1. `Use nusc.field2token()`. Let's try it:

# %%
ann_tokens = nusc.field2token('sample_annotation', 'instance_token', one_instance['token'])

# %% [markdown]
# This returns a list of all sample_annotation records with the `'instance_token'` == `one_instance['token']`. Let's store these in a set for now

# %%
ann_tokens_field2token = set(ann_tokens)

ann_tokens_field2token

# %% [markdown]
# The `nusc.field2token()` method is generic and can be used in any similar situation.
#
# 2. For certain situation, we provide some reverse indices in the tables themselves. This is one such example.

# %% [markdown]
# The instance record has a field `first_annotation_token` which points to the first annotation in time of this instance.
# Recovering this record is easy.

# %%
ann_record = nusc.get('sample_annotation', one_instance['first_annotation_token'])
ann_record

# %% [markdown]
# Now we can traverse all annotations of this instance using the "next" field. Let's try it.

# %%
ann_tokens_traverse = set()
ann_tokens_traverse.add(ann_record['token'])
while not ann_record['next'] == "":
    ann_record = nusc.get('sample_annotation', ann_record['next'])
    ann_tokens_traverse.add(ann_record['token'])

# %% [markdown]
# Finally, let's assert that we recovered the same ann_records as we did using nusc.field2token:

# %%
print(ann_tokens_traverse == ann_tokens_field2token)

# %% [markdown]
# ## Reverse indexing and short-cuts
#
# The nuScenes tables are normalized, meaning that each piece of information is only given once.
# For example, there is one `map` record for each `log` record. Looking at the schema you will notice that the `map` table has a `log_token` field, but that the `log` table does not have a corresponding `map_token` field. But there are plenty of situations where you have a `log`, and want to find the corresponding `map`! So what to do? You can always use the `nusc.field2token()` method, but that is slow and inconvenient. We therefore add reverse mappings for some common situations including this one.
#
# Further, there are situations where one needs to go through several tables to get a certain piece of information.
# Consider, for example, the category name (e.g. `human.pedestrian`) of a `sample_annotation`. The `sample_annotation` table doesn't hold this information since the category is an instance level constant. Instead the `sample_annotation` table points to a record in the `instance` table. This, in turn, points to a record in the `category` table, where finally the `name` fields stores the required information.
#
# Since it is quite common to want to know the category name of an annotation, we add a `category_name` field to the `sample_annotation` table during initialization of the NuScenes class.
#
# In this section, we list the short-cuts and reverse indices that are added to the `NuScenes` class during initialization. These are all created in the `NuScenes.__make_reverse_index__()` method.

# %% [markdown]
# ### Reverse indices
# We add two reverse indices by default.
# * A `map_token` field is added to the `log` records.
# * The `sample` records have shortcuts to all `sample_annotations` for that record as well as `sample_data` key-frames. Confer `nusc.list_sample()` method in the previous section for more details on this.

# %% [markdown]
# ### Shortcuts

# %% [markdown]
# The sample_annotation table has a "category_name" shortcut.

# %% [markdown]
# _Using shortcut:_

# %%
catname = nusc.sample_annotation[0]['category_name']

# %% [markdown]
# _Not using shortcut:_

# %%
ann_rec = nusc.sample_annotation[0]
inst_rec = nusc.get('instance', ann_rec['instance_token'])
cat_rec = nusc.get('category', inst_rec['category_token'])

print(catname == cat_rec['name'])

# %% [markdown]
# The sample_data table has "channel" and "sensor_modality" shortcuts:

# %%
# Shortcut
channel = nusc.sample_data[0]['channel']

# No shortcut
sd_rec = nusc.sample_data[0]
cs_record = nusc.get('calibrated_sensor', sd_rec['calibrated_sensor_token'])
sensor_record = nusc.get('sensor', cs_record['sensor_token'])

print(channel == sensor_record['channel'])

# %% [markdown]
# ## Data Visualizations
#
# We provide list and rendering methods. These are meant both as convenience methods during development, and as tutorials for building your own visualization methods. They are implemented in the NuScenesExplorer class, with shortcuts through the NuScenes class itself.

# %% [markdown]
# ### List methods
# There are three list methods available.

# %% [markdown]
# 1. `list_categories()` lists all categories, counts and statistics of width/length/height in meters and aspect ratio.

# %%
nusc.list_categories()

# %% [markdown]
# 2. `list_attributes()` lists all attributes and counts.

# %%
nusc.list_attributes()

# %% [markdown]
# 3. `list_scenes()` lists all scenes in the loaded DB.

# %%
nusc.list_scenes()

# %% [markdown]
# ### Render

# %% [markdown]
# First, let's plot a lidar point cloud in an image. Lidar allows us to accurately map the surroundings in 3D.

# %%
my_sample = nusc.sample[10]
nusc.render_pointcloud_in_image(my_sample['token'], pointsensor_channel='LIDAR_TOP')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-77e607747cef> in <cell line: 2>()
#       1 my_sample = nusc.sample[10]
# ----> 2 nusc.render_pointcloud_in_image(my_sample['token'], pointsensor_channel='LIDAR_TOP')
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path, render_intensity, show_lidarseg, filter_lidarseg_labels, show_lidarseg_legend, verbose, lidarseg_preds_bin_path, show_panoptic)
#     522                                    lidarseg_preds_bin_path: str = None,
#     523                                    show_panoptic: bool = False) -> None:
# --> 524         self.explorer.render_pointcloud_in_image(sample_token, dot_size, pointsensor_channel=pointsensor_channel,
#     525                                                  camera_channel=camera_channel, out_path=out_path,
#     526                                                  render_intensity=render_intensity,
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path, render_intensity, show_lidarseg, filter_lidarseg_labels, ax, show_lidarseg_legend, verbose, lidarseg_preds_bin_path, show_panoptic)
#    1013         camera_token = sample_record['data'][camera_channel]
#    1014
# -> 1015         points, coloring, im = self.map_pointcloud_to_image(pointsensor_token, camera_token,
#    1016                                                             render_intensity=render_intensity,
#    1017                                                             show_lidarseg=show_lidarseg,
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in map_pointcloud_to_image(self, pointsensor_token, camera_token, min_dist, render_intensity, show_lidarseg, filter_lidarseg_labels, lidarseg_preds_bin_path, show_panoptic)
#     874                                              'render_intensity or show_lidarseg, not both.'
#     875
# --> 876             pc = LidarPointCloud.from_file(pcl_path)
#     877         else:
#     878             pc = RadarPointCloud.from_file(pcl_path)
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/utils/data_classes.py in from_file(cls, file_name)
#     255
#     256         scan = np.fromfile(file_name, dtype=np.float32)
# --> 257         points = scan.reshape((-1, 5))[:, :cls.nbr_dims()]
#     258         return cls(points.T)
#     259
#
# ValueError: cannot reshape array of size 80836 into shape (5)

# %% [markdown]
# In the previous image the colors indicate the distance from the ego vehicle to each lidar point. We can also render the lidar intensity. In the following image the traffic sign ahead of us is highly reflective (yellow) and the dark vehicle on the right has low reflectivity (purple).

# %%
nusc.render_pointcloud_in_image(my_sample['token'], pointsensor_channel='LIDAR_TOP', render_intensity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-bda383123db4> in <cell line: 1>()
# ----> 1 nusc.render_pointcloud_in_image(my_sample['token'], pointsensor_channel='LIDAR_TOP', render_intensity=True)
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path, render_intensity, show_lidarseg, filter_lidarseg_labels, show_lidarseg_legend, verbose, lidarseg_preds_bin_path, show_panoptic)
#     522                                    lidarseg_preds_bin_path: str = None,
#     523                                    show_panoptic: bool = False) -> None:
# --> 524         self.explorer.render_pointcloud_in_image(sample_token, dot_size, pointsensor_channel=pointsensor_channel,
#     525                                                  camera_channel=camera_channel, out_path=out_path,
#     526                                                  render_intensity=render_intensity,
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path, render_intensity, show_lidarseg, filter_lidarseg_labels, ax, show_lidarseg_legend, verbose, lidarseg_preds_bin_path, show_panoptic)
#    1013         camera_token = sample_record['data'][camera_channel]
#    1014
# -> 1015         points, coloring, im = self.map_pointcloud_to_image(pointsensor_token, camera_token,
#    1016                                                             render_intensity=render_intensity,
#    1017                                                             show_lidarseg=show_lidarseg,
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in map_pointcloud_to_image(self, pointsensor_token, camera_token, min_dist, render_intensity, show_lidarseg, filter_lidarseg_labels, lidarseg_preds_bin_path, show_panoptic)
#     874                                              'render_intensity or show_lidarseg, not both.'
#     875
# --> 876             pc = LidarPointCloud.from_file(pcl_path)
#     877         else:
#     878             pc = RadarPointCloud.from_file(pcl_path)
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/utils/data_classes.py in from_file(cls, file_name)
#     255
#     256         scan = np.fromfile(file_name, dtype=np.float32)
# --> 257         points = scan.reshape((-1, 5))[:, :cls.nbr_dims()]
#     258         return cls(points.T)
#     259
#
# ValueError: cannot reshape array of size 80836 into shape (5)

# %% [markdown]
# Second, let's plot the radar point cloud for the same image. Radar is less dense than lidar, but has a much larger range.

# %%
nusc.render_pointcloud_in_image(my_sample['token'], pointsensor_channel='RADAR_FRONT')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-14-1ff1cdd53c62> in <cell line: 1>()
# ----> 1 nusc.render_pointcloud_in_image(my_sample['token'], pointsensor_channel='RADAR_FRONT')
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path, render_intensity, show_lidarseg, filter_lidarseg_labels, show_lidarseg_legend, verbose, lidarseg_preds_bin_path, show_panoptic)
#     522                                    lidarseg_preds_bin_path: str = None,
#     523                                    show_panoptic: bool = False) -> None:
# --> 524         self.explorer.render_pointcloud_in_image(sample_token, dot_size, pointsensor_channel=pointsensor_channel,
#     525                                                  camera_channel=camera_channel, out_path=out_path,
#     526                                                  render_intensity=render_intensity,
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path, render_intensity, show_lidarseg, filter_lidarseg_labels, ax, show_lidarseg_legend, verbose, lidarseg_preds_bin_path, show_panoptic)
#    1013         camera_token = sample_record['data'][camera_channel]
#    1014
# -> 1015         points, coloring, im = self.map_pointcloud_to_image(pointsensor_token, camera_token,
#    1016                                                             render_intensity=render_intensity,
#    1017                                                             show_lidarseg=show_lidarseg,
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in map_pointcloud_to_image(self, pointsensor_token, camera_token, min_dist, render_intensity, show_lidarseg, filter_lidarseg_labels, lidarseg_preds_bin_path, show_panoptic)
#     876             pc = LidarPointCloud.from_file(pcl_path)
#     877         else:
# --> 878             pc = RadarPointCloud.from_file(pcl_path)
#     879         im = Image.open(osp.join(self.nusc.dataroot, cam['filename']))
#     880
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/utils/data_classes.py in from_file(cls, file_name, invalid_states, dynprop_states, ambig_states)
#     386         with open(file_name, 'rb') as f:
#     387             for line in f:
# --> 388                 line = line.strip().decode('utf-8')
#     389                 meta.append(line)
#     390                 if line.startswith('DATA'):
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x95 in position 0: invalid start byte

# %% [markdown]
# We can also plot all annotations across all sample data for that sample. Note how for radar we also plot the velocity vectors of moving objects. Some velocity vectors are outliers, which can be filtered using the settings in RadarPointCloud.from_file()

# %%
my_sample = nusc.sample[20]

# The rendering command below is commented out because it may crash in notebooks
# nusc.render_sample(my_sample['token'])

# %% [markdown]
# Or if we only want to render a particular sensor, we can specify that.

# %%
nusc.render_sample_data(my_sample['data']['CAM_FRONT'])

# %% [markdown]
# Additionally we can aggregate the point clouds from multiple sweeps to get a denser point cloud.

# %%
nusc.render_sample_data(my_sample['data']['LIDAR_TOP'], nsweeps=5, underlay_map=True)
nusc.render_sample_data(my_sample['data']['RADAR_FRONT'], nsweeps=5, underlay_map=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-f99d0d696938> in <cell line: 1>()
# ----> 1 nusc.render_sample_data(my_sample['data']['LIDAR_TOP'], nsweeps=5, underlay_map=True)
#       2 nusc.render_sample_data(my_sample['data']['RADAR_FRONT'], nsweeps=5, underlay_map=True)
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in render_sample_data(self, sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps, out_path, underlay_map, use_flat_vehicle_coordinates, show_lidarseg, show_lidarseg_legend, filter_lidarseg_labels, lidarseg_preds_bin_path, verbose, show_panoptic)
#     555                            lidarseg_preds_bin_path: str = None, verbose: bool = True,
#     556                            show_panoptic: bool = False) -> None:
# --> 557         self.explorer.render_sample_data(sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps=nsweeps,
#     558                                          out_path=out_path,
#     559                                          underlay_map=underlay_map,
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in render_sample_data(self, sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps, out_path, underlay_map, use_flat_vehicle_coordinates, show_lidarseg, show_lidarseg_legend, filter_lidarseg_labels, lidarseg_preds_bin_path, verbose, show_panoptic)
#    1291                 else:
#    1292                     # Get aggregated lidar point cloud in lidar frame.
# -> 1293                     pc, times = LidarPointCloud.from_file_multisweep(self.nusc, sample_rec, chan, ref_chan,
#    1294                                                                      nsweeps=nsweeps)
#    1295                 velocities = None
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/utils/data_classes.py in from_file_multisweep(cls, nusc, sample_rec, chan, ref_chan, nsweeps, min_distance)
#      99         for _ in range(nsweeps):
#     100             # Load up the pointcloud and remove points close to the sensor.
# --> 101             current_pc = cls.from_file(osp.join(nusc.dataroot, current_sd_rec['filename']))
#     102             current_pc.remove_close(min_distance)
#     103
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/utils/data_classes.py in from_file(cls, file_name)
#     255
#     256         scan = np.fromfile(file_name, dtype=np.float32)
# --> 257         points = scan.reshape((-1, 5))[:, :cls.nbr_dims()]
#     258         return cls(points.T)
#     259
#
# ValueError: cannot reshape array of size 82733 into shape (5)

# %% [markdown]
# In the radar plot above we only see very confident radar returns from two vehicles. This is due to the filter settings defined in the file `nuscenes/utils/data_classes.py`. If instead we want to disable all filters and render all returns, we can use the `disable_filters()` function. This returns a denser point cloud, but with many returns from background objects. To return to the default settings, simply call `default_filters()`.

# %%
from nuscenes.utils.data_classes import RadarPointCloud
RadarPointCloud.disable_filters()
nusc.render_sample_data(my_sample['data']['RADAR_FRONT'], nsweeps=5, underlay_map=True)
RadarPointCloud.default_filters()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-18-d63220878bba> in <cell line: 3>()
#       1 from nuscenes.utils.data_classes import RadarPointCloud
#       2 RadarPointCloud.disable_filters()
# ----> 3 nusc.render_sample_data(my_sample['data']['RADAR_FRONT'], nsweeps=5, underlay_map=True)
#       4 RadarPointCloud.default_filters()
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in render_sample_data(self, sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps, out_path, underlay_map, use_flat_vehicle_coordinates, show_lidarseg, show_lidarseg_legend, filter_lidarseg_labels, lidarseg_preds_bin_path, verbose, show_panoptic)
#     555                            lidarseg_preds_bin_path: str = None, verbose: bool = True,
#     556                            show_panoptic: bool = False) -> None:
# --> 557         self.explorer.render_sample_data(sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps=nsweeps,
#     558                                          out_path=out_path,
#     559                                          underlay_map=underlay_map,
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/nuscenes.py in render_sample_data(self, sample_data_token, with_anns, box_vis_level, axes_limit, ax, nsweeps, out_path, underlay_map, use_flat_vehicle_coordinates, show_lidarseg, show_lidarseg_legend, filter_lidarseg_labels, lidarseg_preds_bin_path, verbose, show_panoptic)
#    1297                 # Get aggregated radar point cloud in reference frame.
#    1298                 # The point cloud is transformed to the reference frame for visualization purposes.
# -> 1299                 pc, times = RadarPointCloud.from_file_multisweep(self.nusc, sample_rec, chan, ref_chan, nsweeps=nsweeps)
#    1300
#    1301                 # Transform radar velocities (x is front, y is left), as these are not transformed when loading the
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/utils/data_classes.py in from_file_multisweep(cls, nusc, sample_rec, chan, ref_chan, nsweeps, min_distance)
#      99         for _ in range(nsweeps):
#     100             # Load up the pointcloud and remove points close to the sensor.
# --> 101             current_pc = cls.from_file(osp.join(nusc.dataroot, current_sd_rec['filename']))
#     102             current_pc.remove_close(min_distance)
#     103
#
# /usr/local/lib/python3.10/dist-packages/nuscenes/utils/data_classes.py in from_file(cls, file_name, invalid_states, dynprop_states, ambig_states)
#     386         with open(file_name, 'rb') as f:
#     387             for line in f:
# --> 388                 line = line.strip().decode('utf-8')
#     389                 meta.append(line)
#     390                 if line.startswith('DATA'):
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb5 in position 0: invalid start byte

# %% [markdown]
# We can even render a specific annotation.

# %%
nusc.render_annotation(my_sample['anns'][22])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-f554faae951f> in <cell line: 1>()
# ----> 1 nusc.render_annotation(my_sample['anns'][22])
#
# IndexError: list index out of range

# %% [markdown]
# Finally, we can render a full scene as a video. There are two options here:
# 1. nusc.render_scene_channel() renders the video for a particular channel. (HIT ESC to exit)
# 2. nusc.render_scene() renders the video for all camera channels.
#
# NOTE: These methods use OpenCV for rendering, which doesn't always play nice with IPython Notebooks. If you experience any issues please run these lines from the command line.
#
# Let's grab scene 0061, it is nice and dense.

# %%
my_scene_token = nusc.field2token('scene', 'name', 'scene-0061')[0]

# %%
# The rendering command below is commented out because it may crash in notebooks
# nusc.render_scene_channel(my_scene_token, 'CAM_FRONT')

# %% [markdown]
# There is also a method nusc.render_scene() which renders the video for all camera channels.
# This requires a high-res monitor, and is also best run outside this notebook.

# %%
# The rendering command below is commented out because it may crash in notebooks
# nusc.render_scene(my_scene_token)

# %% [markdown]
# Finally, let us visualize all scenes on the map for a particular location.

# %%
nusc.render_egoposes_on_map(log_location='singapore-onenorth')
